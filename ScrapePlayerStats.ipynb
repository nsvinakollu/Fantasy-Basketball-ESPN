# %%
import requests
import pandas as pd
import json as js
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
# Player Stats for 2021
year = "2021"

url = "https://fantasy.espn.com/basketball/team?leagueId=268439&teamId=3&seasonId=2021"

html = urlopen(url)

soup = BeautifulSoup(html)

# use findALL() to get the column headers
soup.findAll("tr", limit=1)
# use getText()to extract the text we need into a list
headers = [th.getText() for th in soup.findAll("tr", limit=2)[0].findAll("th")]
# exclude the first column as we will not need the ranking order from Basketball Reference for the analysis
headers = headers[1:]
headers.insert(0, "Year")
# Out:
# <!DOCTYPE html>
# <html><head><meta charset="utf-8" class="next-head next-head"/><title class="next-head">Fantasy Basketball Team Clubhouse - ESPN</title><meta content="Play ESPN Fantasy Basketball" name="description"/><meta content="116656161708917" property="fb:app_id"/><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><meta content="Play ESPN Fantasy Basketball" property="og:description"/><meta content="https://g.espncdn.com/s/fbalm/share.png" property="og:image"/><meta content="630" property="og:image:height"/><meta content="1200" property="og:image:width"/><meta content="ESPN.com" property="og:site_name"/><meta content="Fantasy Basketball Team Clubhouse - ESPN" property="og:title"/><meta content="article" property="og:type"/><meta content="https://fantasy.espn.com/basketball/team" property="og:url"/><meta content="summary_large_image" name="twitter:card"/><meta content="Play ESPN Fantasy Basketball" name="twitter:description"/><meta content="https://g.espncdn.com/s/fbalm/share.png" name="twitter:image"/><meta content="espn" name="twitter:site"/><meta content="Fantasy Basketball Team Clubhouse - ESPN" name="twitter:title"/><meta content="https://fantasy.espn.com/basketball/team" name="twitter:url"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link href="//cdn1.espn.net/kona/a5abcf16cafe-1.0.1872/static/espn-ui-extras.css?002331" rel="stylesheet"/><link href="//cdn1.espn.net/kona/a5abcf16cafe-1.0.1872/static/espn-ui.css?002331" rel="stylesheet"/><link href="//cdn1.espn.net/kona/a5abcf16cafe-1.0.1872/static/fixed-data-table.css" rel="stylesheet"/><link as="script" href="//cdn1.espn.net/kona/a5abcf16cafe-1.0.1872/_next/87c109dc-09ac-468b-9eb6-c089d340f0ea/page/basketball/team.js" rel="preload"/><link as="script" href="//cdn1.espn.net/kona/a5abcf16cafe-1.0.1872/_next/87c109dc-09ac-468b-9eb6-c089d340f0ea/page/_app.js" rel="preload"/><link as="script" href="//cdn1.espn.net/kona/a5abcf16cafe-1.0.1872/_next/87c109dc-09ac-468b-9eb6-c089d340f0ea/page/_error.js" rel="preload"/><link as="script" href="//cdn1.espn.net/kona/a5abcf16cafe-1.0.1872/_next/static/commons/main-2eec464fb01f734f87d1.js" rel="preload"/><style id="__jsx-4050260732">body{color:#000;font-family:-apple-system,BlinkMacSystemFont,"Segoe UI","Roboto","Oxygen","Ubuntu","Cantarell","Fira Sans","Droid Sans","Helvetica Neue",sans-serif;font-size:16px;height:100%;margin:0px;padding:0px;}
# main{display:block;}
# .bp-desktopLGPlus{min-width:1240px;}
# .Dropdown__Label{color:#1D1E1F;}
# .shell-container .dropdown__select{color:#151617;padding:0 30px 0 12px;}
# .margin-left-auto{margin-left:auto;}
# .players-table .Table__TH,.players-table .Table__TD{padding:0;}
# .Table__TH,.Table__TD{padding-left:12px;}
# .Table__TBODY,.tbody>.tr{border-bottom:1px solid #DCDDDF;}
# .Table__Colgroup+.Table__Colgroup .Table__Column:nth-child(1){border-left:1px solid #dcdddf;}
# .raised{position:relative;z-index:2;}
# .raised::before,.raised::after{content:'';height:100%;width:5px;position:absolute;top:0;}
# .raised::before{background:linear-gradient(270deg,rgba(0,0,0,.2),transparent);left:-5px;}
# .raised::after{background:linear-gradient(270deg,transparent,rgba(0,0,0,.2));right:-5px;}
# .icon-light{fill:#808080;}
# .layout__column{width:100px;}
# svg,svg use{pointer-events:none;}
# .FavMgmt__Col--Left{min-width:300px;}
# .FavMgmt__Col--Right{max-width:376px;}
# .unselectable{-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}
# .Table__TH.border-right,.Table__TD.border-right{border-right:1px solid #DCDDDF;}
# .tbl-feed-header-text{padding-top:10px;}
# .sponsored-headlines{margin-bottom:0 !important;}
# .ResponsiveTable--fixed-left .total-col[colspan="2"]+.Table__TD{display:none;}</style><style id="__jsx-763806470">.Site__Header{box-shadow:none;}</style><style id="__jsx-1647358489">.bp-desktopPlus .NavMain__SubNav{z-index:1000008;}
# .NavSecondary{box-shadow:0 4px 2px -2px rgba(0,0,0,0.3);}
# .NavSecondary__Item{box-shadow:inset 0 0 0 #ff9000;vertical-align:top;}
# .NavSecondary__Item:not(.branding){overflow:hidden;}
# .NavSecondary__Item:hover{overflow:visible;}
# .NavSecondary__Item:focus-within{overflow:visible;}
# .NavSecondary__Item .NavSecondary__Link .icon-external{width:14px;}
# .NavMain__SubNav__Link:hover,.NavMain__SubNav__List .NavMain__SubNav .NavMain__Link:hover,.NavMain__SubNav__List .NavMain__SubNav__Link:hover{background:#ff9000;color:#fff;}
# .NavMain__SubNav__List .NavMain__SubNav__Link:focus-within{background:#ff9000;color:#fff;}
# .NavSecondary .NavMain__SubNav.NavMain__SubNav--secondary{display:block;}
# .bp-desktopPlus .NavMain__Secondary>.NavSecondary__Item:not(.NavSecondary__Item--brand):hover,.bp-desktopPlus .NavMain__Secondary>.right-subnav>.NavSecondary__Item:not(.NavSecondary__Item--brand):hover,.bp-desktopPlus .NavSecondary__Item.active:not(.NavSecondary__Item--brand){box-shadow:inset 0 -3px 0 #ff9000;}
# .bp-desktopPlus .NavMain__Secondary>.right-subnav>.NavSecondary__Item:not(.NavSecondary__Item--brand):focus-within,.bp-desktopPlus .NavMain__Secondary>.NavSecondary__Item:not(.NavSecondary__Item--brand):focus-within{box-shadow:inset 0 -3px 0 #ff9000;}
# .NavMain__SubNav.myTeams .NavMain__SubNav__Link,.NavMain__SubNav.teams .NavMain__SubNav__Link{display:block;overflow:hidden;height:auto;}
# .NavMain__SubNav.myTeams .NavSecondary__Logo,.NavMain__SubNav.teams .NavSecondary__Logo{height:30px;display:inline-block;width:38px;}
# .NavMain__SubNav.myTeams .NavSecondary__TextContainer,.NavMain__SubNav.teams .NavSecondary__TextContainer{display:inline-block;width:calc(100% - 38px);}
# .NavMain__SubNav .NavSecondary__Logo img{display:block;height:30px;width:30px;}
# .NavMain__SubNav .NavSecondary__Logo img.custom-logo{border-radius:50%;}
# .NavMain__SubNav.myTeams .NavMain__Text,.NavMain__SubNav.teams .NavMain__Text{color:#222;display:block;overflow:hidden;text-overflow:ellipsis;white-space:nowrap;width:auto;}
# .NavMain__SubNav.myTeams .NavMain__Text.sub,.NavMain__SubNav.teams .NavMain__Text.sub{color:#ccc;font-size:11px;width:auto;display:block;}
# .NavMain__SubNav.myTeams .NavMain__SubNav__Link:hover .NavMain__Text,.NavMain__SubNav.teams .NavMain__SubNav__Link:hover .NavMain__Text{color:#fff;}
# .NavMain__SubNav.myTeams .NavMain__SubNav__Link:focus-within .NavMain__Text,.NavMain__SubNav.teams .NavMain__SubNav__Link:focus-within .NavMain__Text{color:#fff;}
# .NavMain__SubNav.is--split .NavMain__SubNav__Item,.NavMain__SubNav.myTeams .NavMain__SubNav__Item,.NavMain__SubNav.teams .NavMain__SubNav__Item{max-width:400px;min-width:200px;list-style:none;display:block;clear:both;white-space:nowrap;}
# .NavMain__SubNav__Item.getAnotherTeam span.NavMain__Text:before{content:'+';padding-right:4px;}
# .NavMain__SubNav.is--split:not(.myTeams):not(.teams) .NavMain__SubNav__Item{min-width:150px;max-width:250px;}
# .NavSecondary .right-subnav{position:absolute;right:0;text-align:right;}
# .NavSecondary .right-subnav .tsn-logo.NavSecondary__Item{vertical-align:top;}
# .NavSecondary .right-subnav .NavMain__SubNav{right:0;left:auto;text-align:left;}
# .NavMain__SubNav.teams .NavMain__SubNav__Item .owners .owner-name + .owner-name::before{content:', ';}
# .NavSecondary ul.NavMain__SubNav__List--secondary{padding:0 8px;min-width:200px;width:auto;}
# .NavSecondary__Link > .icon__svg{height:auto;}
# .NavSecondary .NavSecondary__Split{-ms-flex-preferred-size:auto;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;}
# .NavSecondary .NavSecondary__Item + .tsn-logo.NavSecondary__Item .NavSecondary__Link:before{position:absolute;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);height:calc(100% - 20px);width:1px;left:-1px;content:"";background:#dcdddf;}
# .NavSecondary .tsn-logo.NavSecondary__Item .NavSecondary__Logo{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;}
# .NavSecondary .tsn-logo.NavSecondary__Item img{display:block;}</style><style id="__jsx-979094127">.shell-container.jsx-979094127 .page-container .leagueHistoryModeInShell,.shell-container.jsx-979094127 .page-container .league-deleted{background:#fff;font-size:12px;}
# .shell-container.jsx-979094127 .shell--header .layout__column--1 .container{height:250px;}
# .shell-container.gated.jsx-979094127{background:#fff;position:absolute;height:100%;width:100%;}
# @media only screen and (max-width:425px){.shell-container.gated.jsx-979094127 .signup-closed__container{border-radius:0 !important;}.shell-container.gated.jsx-979094127 .page-container{padding:0 !important;}}
# @media only screen and (min-width:1024px){.shell-container.game-wallpaper.jsx-979094127{background:transparent url(https://g.espncdn.com/lm-static/fba/images/background.png) no-repeat 50% 4px;background-size:1474px 1326px;padding:20px 0;}.shell-container.gated.jsx-979094127 .signup-closed__container{max-width:765px;margin:0 auto;border-radius:10px;}}</style><style id="__jsx-397728423">.container.jsx-397728423{background:#fff;padding:12px 12px 12px 12px;border-radius:10px;}
# .container.gameBorder.jsx-397728423{padding-top:16px;position:relative;}
# .container.gameBorder.jsx-397728423::before{content:'';display:block;position:absolute;top:0;left:0;height:6px;width:100%;background-color:#ff9000;border-radius:10px 10px 0 0;}
# .container.gameBorder.jsx-397728423 .headers.jsx-397728423{margin-top:0;}
# .headers.jsx-397728423{margin:10px 0 6px 0;display:inline-block;}
# .header.jsx-397728423,.subHeader.jsx-397728423{display:inline-block;line-height:32px;vertical-align:top;}
# .header.jsx-397728423{color:#151617;font-size:24px;}
# .header.jsx-397728423+.subHeader.jsx-397728423{margin-left:10px;margin-top:4px;}
# .subHeader.jsx-397728423{color:#4A4A4A;font-weight:normal;font-size:12px;}</style><style id="__jsx-1639273054">.my-team-header.jsx-1639273054{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;line-height:initial;margin:0 2px 2px;height:100%;}
# .my-team-header.jsx-1639273054>.team-logo{margin:0 28px 0 10px;height:88px;}
# .my-team-header.jsx-1639273054 .team-info-container.jsx-1639273054{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;height:88px;width:80%;}
# .my-team-header.jsx-1639273054 .team-info-container.jsx-1639273054>span{display:inline-block;}
# .my-team-header.jsx-1639273054 .team-info-container.jsx-1639273054>span.links-group{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}
# .my-team-header.jsx-1639273054 .team-info-container.jsx-1639273054 .team-details-primary.jsx-1639273054{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;width:100%;}
# .my-team-header.jsx-1639273054 .team-info-container.jsx-1639273054 .team-details-primary.jsx-1639273054 .teamName{font-size:24px;font-weight:700;min-width:12%;}
# .my-team-header.jsx-1639273054 .team-info-container.jsx-1639273054 .team-details-primary.jsx-1639273054 .team-record,.my-team-header.jsx-1639273054 .team-info-container.jsx-1639273054 .team-details-primary.jsx-1639273054 .team-rank{color:#8a8a8a;font-weight:normal;}
# .my-team-header.jsx-1639273054 .team-info-container.jsx-1639273054 .team-details-primary.jsx-1639273054 .team-record{font-size:18px;margin-left:15px;margin-top:5px;white-space:nowrap;}
# .my-team-header.jsx-1639273054 .team-info-container.jsx-1639273054 .team-details-primary.jsx-1639273054 .team-rank{font-size:14px;margin-left:6px;margin-top:8px;min-width:20%;-webkit-box-flex:2;-webkit-flex-grow:2;-ms-flex-positive:2;flex-grow:2;}
# .my-team-header.jsx-1639273054 .team-settings-link{font-size:12px;min-width:15%;-webkit-box-flex:2;-webkit-flex-grow:2;-ms-flex-positive:2;flex-grow:2;}
# .my-team-header.jsx-1639273054 .team-settings-link .icon__svg,.my-team-header.jsx-1639273054 .additional-links.jsx-1639273054 .matchups-display .full-schedule-link .icon__svg{fill:#06c;height:16px;margin-right:4px;vertical-align:text-bottom;width:16px;}
# .my-team-header.jsx-1639273054 .links-group.jsx-1639273054,.my-team-header.jsx-1639273054 .team-details-secondary{font-size:12px;margin:8px 0 0;width:100%;color:#48494a;}
# .my-team-header.jsx-1639273054 .team-details-secondary > .owners{margin-left:12px;padding-left:12px;}
# .my-team-header.jsx-1639273054 .team-details-secondary .owners .owners:not(:only-child) .owner-name::after{content:', ';}
# .my-team-header.jsx-1639273054 .links-group.jsx-1639273054{margin-top:16px;}
# .my-team-header.jsx-1639273054 .links-group.jsx-1639273054 .link-child{font-size:14px;}
# .my-team-header.jsx-1639273054 .links-group.jsx-1639273054 .link-child:not(:first-child){border-left:1px solid #999;margin-left:12px;padding-left:12px;}
# .my-team-header.jsx-1639273054 span.draftPick-ordinal-position{margin-left:5px;}
# .my-team-header.jsx-1639273054 .additional-links.jsx-1639273054{height:107px;margin-top:22px;width:100%;}
# .my-team-header.jsx-1639273054 .additional-links.jsx-1639273054 .Button + .Button{margin-left:20px;}
# .my-team-header.jsx-1639273054 .additional-links.jsx-1639273054 .draft-info{height:100%;}
# .my-team-header.jsx-1639273054 .additional-links.jsx-1639273054 .RotoLine{margin:-10px 0 0;}
# .my-team-header.jsx-1639273054 .additional-links.jsx-1639273054 .matchups-display{margin-top:-2px;}
# .my-team-header.jsx-1639273054 .lightbox__content .confirm-modal-heading{font-size:14px;}
# .my-team-header.jsx-1639273054 .lightbox__content .confirm-modal-content{font-size:12px;color:#666768;background:#fff;padding-bottom:7px;}
# .my-team-header.jsx-1639273054 .email-sent__modal .confirm-modal-content{padding-top:5px;}
# .my-team-header.jsx-1639273054 .email-sent__modal .lightbox__content .Button--alt{background:#0066CC;color:#fff;}
# .my-team-header.jsx-1639273054 .success-lightbox .lightbox__closebtn{right:12px;top:10px;}
# .my-team-header.jsx-1639273054 .confirm-leave-league__modal .Button-confirm-action{background-color:#DD0000;}
# .my-team-header.jsx-1639273054 .confirm-leave-league__modal .Button-confirm-action:hover{background-color:#A00013;}</style><style id="__jsx-3103965902">.success-heading.jsx-3103965902{color:#269D00;font-size:24px;}
# .success-subheading.jsx-3103965902{color:#666768;font-size:12px;}
# .success-icon.jsx-3103965902{height:71px;width:71px;margin:auto;margin-bottom:45px;}
# .success-lightbox.jsx-3103965902 .lightbox__contentBox{width:375px;height:auto;}
# .success-icon.jsx-3103965902 .icon__svg{height:71px;width:71px;fill:#269D00;}</style><style id="__jsx-3807505433">.lightbox__header{min-height:initial;}</style><style id="__jsx-3582151654">.team-draft-picks-container.jsx-3582151654 .lightbox__contentBox{top:150px;position:absolute;margin-bottom:30px;}
# .team-draft-picks-container.jsx-3582151654 .draft-picks-modal-title.jsx-3582151654{margin:26px 0 0 19px;font-size:16px;font-weight:bold;}
# .team-draft-picks-container.jsx-3582151654 .lightbox__closebtn,.team-draft-picks-container.jsx-3582151654 .lightbox__closebtn .icon__svg{height:48px;width:48px;right:8px;}
# .team-draft-picks-container.jsx-3582151654 .lightbox__wrapper{position:fixed;height:100%;overflow-y:auto;}
# .team-draft-picks-container.jsx-3582151654 .lightbox__overlay{-webkit-animation:none;animation:none;opacity:1;width:100%;height:100%;position:fixed;}</style><style id="__jsx-2968158442">.container.jsx-2968158442{background:#fff;padding:12px 12px 12px 12px;border-radius:10px;}
# .container.gameBorder.jsx-2968158442{padding-top:16px;position:relative;}
# .container.gameBorder.jsx-2968158442::before{content:'';display:block;position:absolute;top:0;left:0;height:6px;width:100%;background-color:#ddd;border-radius:10px 10px 0 0;}
# .container.gameBorder.jsx-2968158442 .headers.jsx-2968158442{margin-top:0;}
# .headers.jsx-2968158442{margin:10px 0 6px 0;display:inline-block;}
# .header.jsx-2968158442,.subHeader.jsx-2968158442{display:inline-block;line-height:32px;vertical-align:top;}
# .header.jsx-2968158442{color:#151617;font-size:24px;}
# .header.jsx-2968158442+.subHeader.jsx-2968158442{margin-left:10px;margin-top:4px;}
# .subHeader.jsx-2968158442{color:#4A4A4A;font-weight:normal;font-size:12px;}</style><style id="__jsx-1925058086">.team-page.jsx-1925058086 .players-table{margin-bottom:20px;}
# .team-page.jsx-1925058086 .players-table:last-of-type{margin-bottom:0;}
# .team-page.jsx-1925058086 .content-nav{min-height:50px;}
# .team-page.jsx-1925058086 .action-container{right:0;top:10px;z-index:1;}
# .team-page.jsx-1925058086 .myTeamButtons .action-buttons{min-width:127px;vertical-align:middle;}
# .team-page.jsx-1925058086 .myTeamButtons .action-buttons .icon__svg{fill:#06c;}
# .team-page.jsx-1925058086 .myTeamButtons .action-buttons.Button--disabled .icon__svg{fill:#ccccce;}
# .team-page.jsx-1925058086 .Table__Shadow--left{z-index:0;}
# .team-page.jsx-1925058086 .loader{height:300px;}</style><style id="__jsx-4158115014">.loader.jsx-4158115014{background:#ffffff;position:relative;border-radius:10px;}
# div.overlap-loader.jsx-4158115014{background:rgba(255,255,255,0.80);position:absolute;z-index:9;left:0;top:0;}</style><style id="__jsx-3788716136">#games-footercol.jsx-3788716136 .sl-horizontal,.sl-vertical{background:url('data:image/svg+xml;base64,...') center center no-repeat;background-size:100px;}
# #games-footercol.jsx-3788716136 .sl-horizontal{min-height:100px;}
# #games-footercol.jsx-3788716136 .sl-vertical{min-height:250px;}
# #games-footercol.jsx-3788716136 .sl-wrapper{background:#fff;border-radius:10px;overflow:hidden;padding:0 10px;}
# #games-footercol.jsx-3788716136 .sl-wrapper .ob-widget-items-container,.ob-rec-source{padding-bottom:0 !important;}
# #games-footercol.jsx-3788716136 .sl-wrapper .trc_rbox_header{padding-top:10px !important;}
# #games-footercol.jsx-3788716136 .sl-header{display:none;font-size:14px;font-weight:600;top:12px;}</style><style id="__jsx-1832897612">p.jsx-1832897612{margin:1em 0;}
# footer.jsx-1832897612{color:#666;font-size:10px;padding-left:25px;text-align:center;}</style><style id="__jsx-4255348631">.changes-confirmation-modal.jsx-4255348631 .changes-confirmation-modal__LightBox{height:195px;width:375px;}
# .changes-confirmation-modal.jsx-4255348631 .lightbox__content .confirmation_popup_buttons{width:296px;margin-left:40px;}
# .changes-confirmation-modal.jsx-4255348631 .popup-description{height:60px;width:303px;margin:38px 35px 18px 37px;}</style><style id="__jsx-213266258">.bottomBarContainer.jsx-213266258{z-index:1000;}</style></head><body><div id="__next-wrapper"><div id="__next"><div id="fitt-analytics"><div class="bp-mobileMDPlus bp-mobileLGPlus bp-tabletPlus bp-desktopPlus bp-desktopLGPlus no-touch"><div></div><div class="navigation__container sticky top-0 Site__Header"><div class="jsx-763806470" style="height:44px"><div class="Site__Header db left-0 top-0 sticky w-100 bg-clr-gray-02 Site__Header--espn"><nav class="Nav__Primary center flex justify-between items-center"><div class="Nav__Primary__Branding__Logo"><h1><a class="Nav__Primary__ToggleMenu" href="#"><span>Menu</span></a><a class="AnchorLink Nav__Primary__Branding Nav__Primary__Branding--espn" href="http://www.espn.com" tabindex="0">ESPN</a></h1></div><ul class="Nav__Primary__Menu flex Nav__Primary__Menu--left w-100"><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="http://www.espn.com/nfl/" tabindex="0"><span class="Nav__Text">NFL</span></a></li><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="http://www.espn.com/nba/" tabindex="0"><span class="Nav__Text">NBA</span></a></li><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="http://www.espn.com/soccer/" tabindex="0"><span class="Nav__Text">Soccer</span></a></li><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="http://www.espn.com/college-football/" tabindex="0"><span class="Nav__Text">NCAAF</span></a></li><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="http://www.espn.com/mens-college-basketball/" tabindex="0"><span class="Nav__Text">NCAAM</span></a></li><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="http://www.espn.com/mma/" tabindex="0"><span class="Nav__Text">MMA</span></a></li><li aria-hidden="true" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="http://www.espn.com#" tabindex="-1"><svg class="Nav__Primary__Icon__MoreSports icon__svg" viewbox="0 0 24 24"><use xlink:href="#icon__more__dots"></use></svg></a></li></ul><ul class="Nav__Primary__Menu flex Nav__Primary__Menu--right flex-none"><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="https://www.espn.com/espnplus/?om-navmethod=topnav" tabindex="0"><img alt="ESPN Plus" class="Image Nav__Primary__Icon__ESPNPlus" data-mptype="image" src="..." title="ESPN Plus"/></a></li><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="http://www.espn.com/watch/" tabindex="0"><span class="Nav__Text">Watch</span></a></li><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="http://www.espn.com/espnradio/index" tabindex="0"><span class="Nav__Text">Listen</span></a></li><li aria-hidden="false" class="Nav__Primary__Menu__Item flex-none relative"><a class="AnchorLink Nav__Primary__Menu__Link clr-white flex items-center ns7 ph3" href="http://www.espn.com/fantasy/" tabindex="0"><span class="Nav__Text ...
#           __NEXT_DATA__ = {"props":{"pageProps":{"page":{"config":{"abbreviation":"FBA","acquisitionTypes":["FREEAGENCY","WAIVERS_TRADITIONAL","WAIVERS_CONTINUOUS"],"color":"#ff9000","colorRGB":"255, 144, 0","communicationFilterTypes":{"leagueChatFilter":"MSG_BOARD_GROUP","lmNoteFilter":"NOTE","matchupChatFilter":"MSG_BOARD_MATCHUP","messageBoardFilter":"MSG_BOARD","settingsFilter":"ACTIVITY_SETTINGS","transactionsFilter":"ACTIVITY_TRANSACTIONS","statusFilter":"ACTIVITY_STATUS","pollFilter":"POLL","scheduleFilter":"ACTIVITY_SCHEDULE"},"constants":{"communication":{"messageTypes":[{"active":false,"display":true,"displayOrder":0,"formatRequired":false,"id":0,"name":"CUSTOM"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"ACQUISITION_SETTINGS_LIMIT_CHANGE","id":100,"name":"ACQUISITION_SETTINGS_LIMIT_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"ACQUISITION_SETTINGS_MATCHUP_LIMITS_CHANGE","id":101,"name":"ACQUISITION_SETTINGS_MATCHUP_LIMITS_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"ACQUISITION_SETTINGS_MIN_BID_CHANGE","id":102,"name":"ACQUISITION_SETTINGS_MIN_BID_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"ACQUISITION_SETTINGS_TYPE_CHANGE","id":103,"name":"ACQUISITION_SETTINGS_TYPE_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"ACQUISITION_SETTINGS_WAIVER_HOURS_CHANGE","id":104,"name":"ACQUISITION_SETTINGS_WAIVER_HOURS_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DIVISION_ADD","id":105,"name":"DIVISION_ADD"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DIVISION_MODIFY","id":106,"name":"DIVISION_MODIFY"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DIVISION_REMOVE","id":107,"name":"DIVISION_REMOVE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DIVISIONS_UPDATE","id":108,"name":"DIVISIONS_UPDATE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_CURRENT_KEEPER_CHANGE","id":109,"name":"DRAFT_SETTINGS_CURRENT_KEEPER_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_CURRENT_KEEPER_DATE_CHANGE","id":110,"name":"DRAFT_SETTINGS_CURRENT_KEEPER_DATE_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_DATE_CHANGE","id":111,"name":"DRAFT_SETTINGS_DATE_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_FUTURE_KEEPER_CHANGE","id":112,"name":"DRAFT_SETTINGS_FUTURE_KEEPER_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_FUTURE_KEEPER_DATE_CHANGE","id":113,"name":"DRAFT_SETTINGS_FUTURE_KEEPER_DATE_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_ORDER_CHANGE","id":114,"name":"DRAFT_SETTINGS_ORDER_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_ORDERTYPE_CHANGE","id":115,"name":"DRAFT_SETTINGS_ORDERTYPE_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_TIME_PER_SELECTION_CHANGE","id":116,"name":"DRAFT_SETTINGS_TIME_PER_SELECTION_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_TRADING_CHANGE","id":117,"name":"DRAFT_SETTINGS_TRADING_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_SETTINGS_TYPE_CHANGE","id":118,"name":"DRAFT_SETTINGS_TYPE_CHANGE"},{"active":false,"display":true,"displayOrder":0,"formatRequired":true,"fromEventType":"DRAFT_STATUS_DRAFT ...
#           module={}
#           __NEXT_LOADED_PAGES__ = []
#           __NEXT_LOADED_CHUNKS__ = []
#
#           __NEXT_REGISTER_PAGE = function (route, fn) {
#             __NEXT_LOADED_PAGES__.push({ route: route, fn: fn })
#           }
#
#           __NEXT_REGISTER_CHUNK = function (chunkName, fn) {
#             __NEXT_LOADED_CHUNKS__.push({ chunkName: chunkName, fn: fn })
#           }
#
#           false
#         </script><script async="" id="__NEXT_PAGE__/basketball/team" src="//cdn1.espn.net/kona/a5abcf16cafe-1.0.1872/_next/87c109dc-09ac-468b-9eb6-c089d340f0ea/page/basketball/team.js"></script><script async="" id="__NEXT_PAGE__/_app" src="//cdn1.espn.net/kona/a5abcf16cafe-1.0.1872/_next/87c109dc-09ac-468b-9eb6-c089d340f0ea/page/_app.js"></script><script async="" id="__NEXT_PAGE__/_error" src="//cdn1.espn.net/kona/a5abcf16cafe-1.0.1872/_next/87c109dc-09ac-468b-9eb6-c089d340f0ea/page/_error.js"></script><script async="" src="//cdn1.espn.net/kona/a5abcf16cafe-1.0.1872/_next/static/commons/main-2eec464fb01f734f87d1.js"></script></body></html>
